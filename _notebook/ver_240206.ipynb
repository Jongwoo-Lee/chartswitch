# %%
import atexit
import signal
from thread_manager import ThreadManager
from main import main, signal_handler

thread_manager = ThreadManager()
atexit.register(thread_manager.cleanup)
signal.signal(signal.SIGINT, signal_handler)
signal.signal(signal.SIGTERM, signal_handler)

main(thread_manager)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import atexit
#       2 import signal
# ----> 3 from thread_manager import ThreadManager
#       4 from main import main, signal_handler
#       6 thread_manager = ThreadManager()
#
# ModuleNotFoundError: No module named 'thread_manager'
